# %%
fig = plt.figure()
ims = []
 
for i in range(100):
    rand = np.random.randn(100) # 100個の乱数を作成
    
    img = plt.plot(rand) # グラフを作成
    plt.title("sample animation")
    plt.ylim(-10,10)
 
    ims.append(img) # グラフを配列に追加
 
 
 
# 100枚のプロットを 100ms ごとに表示するアニメーション
ani = animation.ArtistAnimation(fig, ims, interval=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# !ls
# Out:
# Distortion_plot_simple.ipynb  animation.ipynb  order.ipynb  text.txt
# README.md		      get_plots.ipynb  resul.csv
